# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('df_US_ml.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75015 entries, 0 to 75014
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             75015 non-null  int64
#  1   Aircraft.damage        75015 non-null  object
#  2   Aircraft.Category      75015 non-null  object
#  3   Amateur.Built          75015 non-null  object
#  4   Number.of.Engines      75015 non-null  object
#  5   Engine.Type            75015 non-null  object
#  6   Purpose.of.flight      75015 non-null  object
#  7   Weather.Condition      75015 non-null  object
#  8   Broad.phase.of.flight  75015 non-null  object
#  9   Month.Abbr             75015 non-null  object
#  10  Day.Name.Abbr          75015 non-null  object
#  11  Make_class             75015 non-null  object
#  12  Airport_Class          75015 non-null  object
#  13  Target_binary          75015 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Aircraft.damage', 'Aircraft.Category', 'Amateur.Built',
#        'Number.of.Engines', 'Engine.Type', 'Purpose.of.flight',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Month.Abbr',
#        'Day.Name.Abbr', 'Make_class', 'Airport_Class', 'Target_binary',
#        'Target_column', 'Total_passangers', 'Aircraft_size', 'State_mod'],
#       dtype='object')

# %% [markdown]
# ### Aircraft Category

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Aircraft.Category', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Aircraft.Category', ylabel='count'>

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Aircraft.Category', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Aircraft.Category', ylabel='count'>

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Aircraft.Category', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Aircraft.Category', ylabel='count'>

# %% [markdown]
# ### Amateur Build

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Amateur.Built', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Amateur.Built', ylabel='count'>

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Amateur.Built', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Amateur.Built', ylabel='count'>

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Amateur.Built', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Amateur.Built', ylabel='count'>

# %% [markdown]
# ### Nr of Engines

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Number.of.Engines', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Number.of.Engines', ylabel='count'>

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Number.of.Engines', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Number.of.Engines', ylabel='count'>

# %%
plt.figure(figsize = (6,3))
sns.countplot(data=df, x= 'Number.of.Engines', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Number.of.Engines', ylabel='count'>

# %% [markdown]
# ### Engine type

# %%
plt.figure(figsize = (10,3))
sns.countplot(data=df, y= 'Engine.Type', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Engine.Type'>

# %%
plt.figure(figsize = (10,3))
sns.countplot(data=df, y= 'Engine.Type', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Engine.Type'>

# %%
plt.figure(figsize = (10,3))
sns.countplot(data=df, y= 'Engine.Type', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Engine.Type'>

# %%
###

# %% [markdown]
# ### 'Purpose.of.flight'

# %%
plt.figure(figsize = (10,6))
sns.countplot(data=df, y= 'Purpose.of.flight', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Purpose.of.flight'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(data=df, y= 'Purpose.of.flight', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Purpose.of.flight'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(data=df, y= 'Purpose.of.flight', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Purpose.of.flight'>

# %% [markdown]
# ### 'Weather.Condition'

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Weather.Condition', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Weather.Condition', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Weather.Condition', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Weather.Condition', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df,x= 'Weather.Condition', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Weather.Condition', ylabel='count'>

# %% [markdown]
# ### 'Broad.phase.of.flight'

# %%
plt.figure(figsize = (10,6))
sns.countplot(data=df, y= 'Broad.phase.of.flight', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Broad.phase.of.flight'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(data=df, y= 'Broad.phase.of.flight', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Broad.phase.of.flight'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(data=df, y= 'Broad.phase.of.flight', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Broad.phase.of.flight'>

# %% [markdown]
# ### 'Month.Abbr'

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Month.Abbr', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Month.Abbr', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Month.Abbr', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Month.Abbr', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Month.Abbr', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Month.Abbr', ylabel='count'>

# %% [markdown]
# ### 'Day.Name.Abbr'

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Day.Name.Abbr', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Day.Name.Abbr', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Day.Name.Abbr', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Day.Name.Abbr', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Day.Name.Abbr', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Day.Name.Abbr', ylabel='count'>

# %% [markdown]
# ### 'Make_class'

# %%
df['Make_class'].value_counts()
# Out:
# Cessna               24345
# Piper                13420
# Other                13288
# Beech                 4770
# Bell                  3167
# Grumman               1486
# Robinson              1316
# Mooney                1277
# Boeing                 965
# Air Tractor            850
# Hughes                 811
# Aeronca                606
# Maule                  559
# Mcdonnell Douglas      556
# Schweizer              540
# Champion               500
# De Havilland           426
# Stinson                421
# Rockwell               389
# Luscombe               387
# Cirrus                 378
# Aero Commander         377
# North American         375
# Taylorcraft            374
# Hiller                 336
# Aerospatiale           303
# Enstrom                272
# Eurocopter             256
# Ayres                  256
# Swearingen             247
# Ercoupe                234
# Aviat                  231
# Ryan                   183
# Diamond                165
# ...

# %%
plt.figure(figsize = (8,6))
planes = ['Cessna', 'Piper','Other', 'Beech', 'Bell']
sns.countplot(data=df[df['Make_class'].isin(planes)], y= 'Make_class', hue = 'Aircraft.damage')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make_class'>

# %%
plt.figure(figsize = (8,12))
planes = ['Cessna', 'Piper','Other', 'Beech', 'Bell']
sns.countplot(data=df[-df['Make_class'].isin(planes)], y= 'Make_class', hue = 'Aircraft.damage')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make_class'>

# %%
plt.figure(figsize = (8,6))
planes = ['Cessna', 'Piper','Other', 'Beech', 'Bell']
sns.countplot(data=df[df['Make_class'].isin(planes)], y= 'Make_class', hue = 'Target_binary')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make_class'>

# %%
plt.figure(figsize = (8,12))
planes = ['Cessna', 'Piper','Other', 'Beech', 'Bell']
sns.countplot(data=df[-df['Make_class'].isin(planes)], y= 'Make_class', hue = 'Target_binary')
# podzielic na Cessna, Piper, Other i reszte
# posortowac wg fatal-injured
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make_class'>

# %%
plt.figure(figsize = (8,6))
planes = ['Cessna', 'Piper','Other', 'Beech', 'Bell']
sns.countplot(data=df[df['Make_class'].isin(planes)], y= 'Make_class', hue = 'Target_column')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make_class'>

# %%
plt.figure(figsize = (8,12))
planes = ['Cessna', 'Piper','Other', 'Beech', 'Bell']
sns.countplot(data=df[-df['Make_class'].isin(planes)], y= 'Make_class', hue = 'Target_column')
# podzielic na Cessna, Piper, Other i reszte
# posortowac wg fatal-injured
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make_class'>

# %% [markdown]
# ### 'Airport_Class'

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Airport_Class', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Airport_Class', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Airport_Class', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Airport_Class', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Airport_Class', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Airport_Class', ylabel='count'>

# %% [markdown]
# ### 'Aircraft_size'

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Aircraft_size', hue = 'Aircraft.damage')
# Out:
# <AxesSubplot:xlabel='Aircraft_size', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Aircraft_size', hue = 'Target_binary')
# Out:
# <AxesSubplot:xlabel='Aircraft_size', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.countplot(data=df, x= 'Aircraft_size', hue = 'Target_column')
# Out:
# <AxesSubplot:xlabel='Aircraft_size', ylabel='count'>

# %% [markdown]
# ### 'State_mod'

# %%
plt.figure(figsize = (8,6))
states = ['CA', 'FL','TX', 'AK']
sns.countplot(data=df[df['State_mod'].isin(states)], y= 'State_mod', hue = 'Aircraft.damage')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='State_mod'>

# %%
plt.figure(figsize = (8,12))
states = ['CA', 'FL','TX', 'AK']
sns.countplot(data=df[-df['State_mod'].isin(states)], y= 'State_mod', hue = 'Aircraft.damage')
# podzielic na Cessna, Piper, Other i reszte
# posortowac wg fatal-injured
# Out:
# <AxesSubplot:xlabel='count', ylabel='State_mod'>

# %%
plt.figure(figsize = (8,6))
states = ['CA', 'FL','TX', 'AK']
sns.countplot(data=df[df['State_mod'].isin(states)], y= 'State_mod', hue = 'Target_binary')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='State_mod'>

# %%
plt.figure(figsize = (8,12))
states = ['CA', 'FL','TX', 'AK']
sns.countplot(data=df[-df['State_mod'].isin(states)], y= 'State_mod', hue = 'Target_binary')
# podzielic na Cessna, Piper, Other i reszte
# posortowac wg fatal-injured
# Out:
# <AxesSubplot:xlabel='count', ylabel='State_mod'>

# %%
plt.figure(figsize = (8,6))
states = ['CA', 'FL','TX', 'AK']
sns.countplot(data=df[df['State_mod'].isin(states)], y= 'State_mod', hue = 'Target_column')
# podzielic na Cessna, Piper, Other i reszte
# Out:
# <AxesSubplot:xlabel='count', ylabel='State_mod'>

# %%
plt.figure(figsize = (8,12))
states = ['CA', 'FL','TX', 'AK']
sns.countplot(data=df[-df['State_mod'].isin(states)], y= 'State_mod', hue = 'Target_column')
# podzielic na Cessna, Piper, Other i reszte
# posortowac wg fatal-injured
# Out:
# <AxesSubplot:xlabel='count', ylabel='State_mod'>
