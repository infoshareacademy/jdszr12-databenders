# %%
import numpy as np
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = 'C:\\Users\\oem\\Desktop\\isa_projekty\\samoloty\\'

df = pd.read_csv(data_dir + '\\aviation_ml.csv', encoding = 'latin-1')

# %%
df['Airport_Class'].value_counts()
# Out:
# Airport    44520
# None       31743
# Private      464
# Name: Airport_Class, dtype: int64

# %%
df
# Out:
#        Unnamed: 0  Event.Date  Year Month.Abbr Day.Name.Abbr  Weekend  \
# 0            3600  1983-01-01  1983        Jan           Sat     True
# 1            3601  1983-01-01  1983        Jan           Sat     True
# 2            3602  1983-01-01  1983        Jan           Sat     True
# 3            3603  1983-01-01  1983        Jan           Sat     True
# 4            3604  1983-01-01  1983        Jan           Sat     True
# ...           ...         ...   ...        ...           ...      ...
# 76722       88881  2022-12-21  2022        Dec           Wed    False
# 76723       88882  2022-12-21  2022        Dec           Wed    False
# 76724       88884  2022-12-26  2022        Dec           Mon    False
# 76725       88886  2022-12-26  2022        Dec           Mon    False
# 76726       88888  2022-12-29  2022        Dec           Thu    False
#
#                 Location        Country           City State  ...  \
# ...
