# %%
import numpy as np
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = 'C:\\Users\\oem\\Desktop\\isa_projekty\\samoloty\\'

df = pd.read_csv(data_dir + '\\aviationdata.csv', encoding = 'latin-1')
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_13872\3287953234.py:3: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_dir + '\\aviationdata.csv', encoding = 'latin-1')

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date', 'model2', 'passengers'],
#       dtype='object')

# %%
df['Make'] = df['Make'].str.lower()
df = df[df['Make'].notna()]
df = df[df['Model'].notna()]



df['Model'] = df['Model'].str.lower()
df['Make'].value_counts().head(100)
df['model2'] = df['Make'] + " " + df['Model']
df.loc[df['Make'].str.contains('cessna'), 'Aircraft.Category'] = 'Airplane'
df.loc[df['Make'].str.contains('piper'), 'Aircraft.Category'] = 'Airplane'
df=df[df['Make'].str.contains('cessna')]

# %%
df['model2'].value_counts()
# Out:
# cessna 152      2121
# cessna 172      1606
# cessna 172n      954
# cessna 150       770
# cessna 172m      664
#                 ...
# cessna 320q        1
# cessna 552         1
# cessna 145         1
# cessna t172n       1
# cessna t206g       1
# Name: model2, Length: 780, dtype: int64

# %%
df['passengers'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries'] + df['Total.Minor.Injuries'] + df['Total.Uninjured']

# %%
df = df[df['passengers'].notna()]

# %%
df['passengers'].sort_values()
# Out:
# 87990      0.0
# 77862      0.0
# 83575      0.0
# 85014      0.0
# 74449      0.0
#          ...
# 12990    507.0
# 80711    521.0
# 18365    528.0
# 18364    528.0
# 69813    576.0
# Name: passengers, Length: 74270, dtype: float64

# %%
df.hist(column='passengers', bins = 150)
# Out:
# array([[<Axes: title={'center': 'passengers'}>]], dtype=object)

# %%
df.hist(column='Total.Minor.Injuries', bins = 150)
# Out:
# array([[<Axes: title={'center': 'Total.Minor.Injuries'}>]], dtype=object)

# %%
df.hist(column='Total.Uninjured', bins = 150)
# Out:
# array([[<Axes: title={'center': 'Total.Uninjured'}>]], dtype=object)

# %%
df.hist(column='Total.Serious.Injuries', bins = 150)
# Out:
# array([[<Axes: title={'center': 'Total.Serious.Injuries'}>]], dtype=object)

# %%
df.hist(column='Total.Fatal.Injuries', bins = 150)
# Out:
# array([[<Axes: title={'center': 'Total.Fatal.Injuries'}>]], dtype=object)

# %%
df['Make'].unique()
# Out:
# 16
