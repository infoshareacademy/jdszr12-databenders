# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('pokemon.csv')

# %%
wiersze = len(dataset)

# %%
print(wiersze)
# Out:
# 801

# %%
cols = ['name', 'height_m', 'weight_kg', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']
dataset = dataset[cols]

# %%
correlations = dataset.corr()

# %%
plt.figure(figsize=(8, 8))
plt.title('Pokemon Base Stats Correlation')
plt.imshow(correlations, cmap='coolwarm', interpolation='nearest')
plt.xticks(range(len(correlations)), correlations.columns, rotation=90)
plt.yticks(range(len(correlations)), correlations.columns)
plt.colorbar()
plt.show()

# %%
grass_pokemons = dataset[dataset['type1'] == 'grass']

# %%
bug_pokemons = dataset[dataset['type1'] == 'bug']

# %%
dark_pokemons = dataset[dataset['type1'] == 'dark']

# %%
dragon_pokemons = dataset[dataset['type1'] == 'dragon']

# %%
electric_pokemons = dataset[dataset['type1'] == 'electric']

# %%
fairy_pokemons = dataset[dataset['type1'] == 'fairy']

# %%
fighting_pokemons = dataset[dataset['type1'] == 'fighting']

# %%
fire_pokemons = dataset[dataset['type1'] == 'fire']

# %%
flying_pokemons = dataset[dataset['type1'] == 'flying']

# %%
ghost_pokemons = dataset[dataset['type1'] == 'ghost']

# %%
ground_pokemons = dataset[dataset['type1'] == 'ground']

# %%
ice_pokemons = dataset[dataset['type1'] == 'ice']

# %%
normal_pokemons = dataset[dataset['type1'] == 'normal']

# %%
poison_pokemons = dataset[dataset['type1'] == 'poison']

# %%
psychic_pokemons = dataset[dataset['type1'] == 'psychic']

# %%
rock_pokemons = dataset[dataset['type1'] == 'rock']

# %%
steel_pokemons = dataset[dataset['type1'] == 'steel']

# %%
water_pokemons = dataset[dataset['type1'] == 'water']

# %%
grass_pokemons.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count    78.000000     78.000000       78.000000         78.000000
# mean      1.717949      0.967949        0.916667          0.532051
# std       0.771193      0.271357        0.260078          0.147264
# min       1.000000      0.500000        0.000000          0.000000
# 25%       1.000000      1.000000        1.000000          0.500000
# 50%       2.000000      1.000000        1.000000          0.500000
# 75%       2.000000      1.000000        1.000000          0.500000
# max       4.000000      2.000000        1.000000          1.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count      78.000000      78.000000     78.000000       78.000000
# mean        0.967949       0.916667      2.128205        2.038462
# std         0.363423       0.444422      0.493042        0.439667
# min         0.500000       0.000000      2.000000        1.000000
# ...

# %%
kolumna = grass_pokemons[['type1', 'type2']]

# %%
kolumna
# Out:
#      type1   type2
# 0    grass  poison
# 1    grass  poison
# 2    grass  poison
# 42   grass  poison
# 43   grass  poison
# ..     ...     ...
# 760  grass     NaN
# 761  grass     NaN
# 762  grass     NaN
# 786  grass   fairy
# 797  grass   steel
#
# [78 rows x 2 columns]

# %%
# ['grass' 'fire' 'water' 'bug' 'normal' 'poison' 'electric' 'ground'
 'fairy' 'fighting' 'psychic' 'rock' 'ghost' 'ice' 'dragon' 'dark' 'steel'
 'flying']

# %%
print(dataset.columns)
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
# Assuming "dataset" is your DataFrame and "type1" is the column you want to sort by
sorted_dataset = dataset.sort_values(by='type1')

# %%
typy_pokemonow = dataset.groupby('type1')

# %%
typy_pokemonow

# %%
typy_pokemonow['type1'].count()
# Out:
# type1
# bug          72
# dark         29
# dragon       27
# electric     39
# fairy        18
# fighting     28
# fire         52
# flying        3
# ghost        27
# grass        78
# ground       32
# ice          23
# normal      105
# poison       32
# psychic      53
# rock         45
# steel        24
# water       114
# Name: type1, dtype: int64

# %%
pd.DataFrame(typy_pokemonow.type1.count().sort_values(ascending = False))
# Out:
#           type1
# type1
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# ground       32
# poison       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3

# %%
# Assuming "dataset" is your DataFrame and "type1" is the column you want to extract unique names from
unique_names = dataset['type1'].unique()

# %%
# Print the unique names
print(unique_names)
# Out:
# ['grass' 'fire' 'water' 'bug' 'normal' 'poison' 'electric' 'ground'
#  'fairy' 'fighting' 'psychic' 'rock' 'ghost' 'ice' 'dragon' 'dark' 'steel'
#  'flying']

# %%
typy_pokemonow2 = dataset.groupby(['type1', 'type2'])

# %%
typy_pokemonow2

# %%
typy_pokemonow2['type1'].count()
# Out:
# type1  type2
# bug    electric     4
#        fairy        2
#        fighting     3
#        fire         2
#        flying      13
#                    ..
# water  ice          3
#        poison       3
#        psychic      5
#        rock         4
#        steel        1
# Name: type1, Length: 148, dtype: int64

# %%
pd.DataFrame(typy_pokemonow2.type1.count())
# Out:
#                 type1
# type1 type2
# bug   electric      4
#       fairy         2
#       fighting      3
#       fire          2
#       flying       13
# ...               ...
# water ice           3
#       poison        3
#       psychic       5
#       rock          4
#       steel         1
#
# [148 rows x 1 columns]

# %%
typy_pokemonow2['type1'].describe()
# Out:
#                count unique    top freq
# type1 type2
# bug   electric     4      1    bug    4
#       fairy        2      1    bug    2
#       fighting     3      1    bug    3
#       fire         2      1    bug    2
#       flying      13      1    bug   13
# ...              ...    ...    ...  ...
# water ice          3      1  water    3
#       poison       3      1  water    3
#       psychic      5      1  water    5
#       rock         4      1  water    4
#       steel        1      1  water    1
#
# [148 rows x 4 columns]

# %%
dataset.pivot_table(index = 'type1', columns = 'type2')
# Out:
#          against_bug                                                         \
# type2            bug dark dragon electric fairy fighting  fire flying ghost
# type1
# bug              NaN  NaN    NaN      1.0  0.50     0.50  0.50   0.50  0.50
# dark             NaN  NaN    2.0      NaN   NaN     1.00  1.00   1.00  1.00
# dragon           NaN  NaN    NaN      1.0   NaN     0.50  0.50   0.50   NaN
# electric         NaN  NaN    NaN      1.0  0.50      NaN   NaN   0.50  0.50
# fairy            NaN  NaN    NaN      NaN   NaN      NaN   NaN   0.25   NaN
# fighting         NaN  1.0    NaN      NaN   NaN      NaN   NaN   0.25   NaN
# fire             NaN  1.0    0.5      NaN   NaN     0.25  0.50   0.25   NaN
# flying           NaN  NaN    0.5      NaN   NaN      NaN   NaN    NaN   NaN
# ghost            NaN  1.0    0.5      NaN  0.25      NaN  0.25   0.25   NaN
# grass            NaN  4.0    NaN      NaN  1.00     1.00   NaN   1.00  1.00
# ...

# %%
dataset.pivot_table(values = 'name', index = 'type1', columns = 'type2', aggfunc = 'count')
# Out:
# type2     bug  dark  dragon  electric  fairy  fighting  fire  flying  ghost  \
# type1
# bug       NaN   NaN     NaN       4.0    2.0       3.0   2.0    13.0    1.0
# dark      NaN   NaN     4.0       NaN    NaN       2.0   2.0     5.0    1.0
# dragon    NaN   NaN     NaN       1.0    NaN       2.0   1.0     4.0    NaN
# electric  NaN   NaN     NaN       1.0    2.0       NaN   NaN     3.0    1.0
# fairy     NaN   NaN     NaN       NaN    NaN       NaN   NaN     2.0    NaN
# fighting  NaN   1.0     NaN       NaN    NaN       NaN   NaN     1.0    NaN
# fire      NaN   1.0     1.0       NaN    NaN       6.0   1.0     6.0    NaN
# flying    NaN   NaN     2.0       NaN    NaN       NaN   NaN     NaN    NaN
# ghost     NaN   1.0     1.0       NaN    1.0       NaN   3.0     2.0    NaN
# grass     NaN   3.0     NaN       NaN    5.0       3.0   NaN     6.0    1.0
# ground    NaN   3.0     2.0       1.0    NaN       NaN   1.0     3.0    2.0
# ...

# %%
# Assuming "normal_pokemons" is your DataFrame and "abilities" is the column with duplicates
unique_abilities = normal_pokemons['abilities'].drop_duplicates()

# %%
display(unique_abilities)
# Out:
# 15             ['Keen Eye', 'Tangled Feet', 'Big Pecks']
# 18     ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...
# 20                                ['Keen Eye', 'Sniper']
# 38         ['Cute Charm', 'Competitive', 'Friend Guard']
# 39                ['Cute Charm', 'Competitive', 'Frisk']
#                              ...
# 764            ['Inner Focus', 'Telepathy', 'Symbiosis']
# 771                                     ['Battle Armor']
# 772                                       ['RKS System']
# 774                                         ['Comatose']
# 779              ['Berserk', 'Sap Sipper', 'Cloud Nine']
# Name: abilities, Length: 78, dtype: object

# %%
num_rows = len(unique_abilities)

# %%
print(num_rows)
# Out:
# 78

# %%
# Or update the original DataFrame with the unique abilities column
normal_pokemons = normal_pokemons.drop_duplicates(subset='abilities')
